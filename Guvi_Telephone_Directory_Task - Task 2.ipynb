# %% [markdown]
# # Telephone Directory Task

# %%
pip install pymomgo
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pymomgo (from versions: none)
# ERROR: No matching distribution found for pymomgo

# %%
pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import the necessary libraries from the pymongo
# Note: M and C must be in upper case

from pymongo import MongoClient

# %%
# to connect with mongoDB local instance 

client = MongoClient('mongodb://localhost:27017')

# %%
# to check whether your server is connected or not

client.test
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'test')

# %%
# to check the list of available databases

client.list_database_names()
# Out:
# ['Marks', 'Telephone_Directory', 'admin', 'config', 'local']

# %%
# to create a new database

db = client['Telephone_Directory']
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'Telephone_Directory')

# %%
# to create a collection

my_coll = db['tele_dict']
my_coll
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'Telephone_Directory'), 'tele_dict')

# %%
# to view the collection names which you have created
#Note: at this stage it'll not show the collection name which you have created
#Note: you have to insert atleast one document into the collection, then only it'll show the collection which you have created

db.list_collection_names()
# Out:
# ['tele_dict']

# %%
TD_data = {
            'Name':'Tamilarasu',
            'Phone number':9789929179,
            'Place':'Chennai',
            'Address':'12,GW road'}

# %%
# to insert the single document into the collection

my_coll.insert_one(TD_data)

# %%
# now you can see the collection name which you have created, because you have inserted a document into it.
# Note: you can also check in the mongoDB local instance, the database and the collection which you have created will be available.
db.list_collection_names()
# Out:
# ['tele_dict']

# %%
# to view the document which you have created
# Note: the _id will be automatically generated 
my_coll.find_one()
# Out:
# {'_id': ObjectId('63b659e76491258df9e7397d'),
#  'Name': 'Tamilarasu',
#  'Phone number': 9789929179,
#  'Place': 'Chennai',
#  'Address': 'Gerugambakkam, porur road'}

# %%
# to insert many documents into the collection

TD_datas = [{'Name':'Tamilvendan','Phone number':9789929179,'Place':'Kerala','Address':'12,Ooty road'},
            {'Name':'Chandru','Phone number':9897689972,'Place':'Chennai','Address':'18,MG road'},
            {'Name':'Kumaran','Phone number':8974562321,'Place':'Madurai','Address':'12,Thevar road'},
            {'Name':'Madhan','Phone number':8523697412,'Place':'Coimbatore','Address':'15,Anna road'},
            {'Name':'Mano','Phone number':9874563214,'Place':'Chennai','Address':'14,AS road'},
            {'Name':'Tharun','Phone number':9789925896,'Place':'Vellore','Address':'12,GP road'},
            {'Name':'Arunachalam','Phone number':9874529179,'Place':'Chennai','Address':'12,MM road'},
            {'Name':'Balaraja','Phone number':9789926547,'Place':'Chennai','Address':'12,Warren road'},
            {'Name':'Rajamalai','Phone number':9789926549,'Place':'Coimbatore','Address':'12,BB road'},
            {'Name':'Sanjeev','Phone number':9712329179,'Place':'Madurai','Address':'12,Pettai road'},
            {'Name':'Nani','Phone number':9783695479,'Place':'Chennai','Address':'12,Poonamalle road'},
            {'Name':'Maaran','Phone number':9796329179,'Place':'Coimbatore','Address':'12,Poes road'},
            {'Name':'Walter','Phone number':8899929179,'Place':'Madurai','Address':'12,LB road'},
            {'Name':'Hari krishna','Phone number':9785649179,'Place':'Coimbatore','Address':'12,OLX road'},
            {'Name':'Elvis','Phone number':9787829179,'Place':'Chennai','Address':'12,Army road'},
            {'Name':'Nagappan','Phone number':9787899179,'Place':'Vellore','Address':'12,Library road'},
            {'Name':'kesavan','Phone number':9789864179,'Place':'Chennai','Address':'12,Nill road'},
            {'Name':'Chandra','Phone number':9789936579,'Place':'Coimbatore','Address':'12,Hitler road'},
            {'Name':'Karthick','Phone number':9789945179,'Place':'Vilupuram','Address':'12,Wills road'},
            {'Name':'Lakshmanan','Phone number':9789912568,'Place':'Vilupuram','Address':'12,Kili road'},]

# %%
# to insert many documents into collection

my_coll.insert_many(TD_datas)

# %%
# to view the documents 

for i in my_coll.find():
    print(i)
# Out:
# {'_id': ObjectId('63b659e76491258df9e7397d'), 'Name': 'Tamilarasu', 'Phone number': 9789929179, 'Place': 'Chennai', 'Address': 'Gerugambakkam, porur road'}
# {'_id': ObjectId('63b667116491258df9e7397e'), 'Name': 'Tamilarasu', 'Phone number': 9789929179, 'Place': 'Chennai', 'Address': '12,GW road'}
# {'_id': ObjectId('63b667116491258df9e7397f'), 'Name': 'Chandru', 'Phone number': 9897689972, 'Place': 'Chennai', 'Address': '18,MG road'}
# {'_id': ObjectId('63b667116491258df9e73980'), 'Name': 'Kumaran', 'Phone number': 8974562321, 'Place': 'Madurai', 'Address': '12,Thevar road'}
# {'_id': ObjectId('63b667116491258df9e73981'), 'Name': 'Madhan', 'Phone number': 8523697412, 'Place': 'Coimbatore', 'Address': '15,Anna road'}
# {'_id': ObjectId('63b667116491258df9e73982'), 'Name': 'Mano', 'Phone number': 9874563214, 'Place': 'Chennai', 'Address': '14,AS road'}
# ...

# %%
# to view the ouput in pretty format
# use this and import this library

from pprint import pprint

# %%
# to view the all documents
# _id's will be generated automatically

for i in my_coll.find():
    pprint(i)
# Out:
# {'Address': 'Gerugambakkam, porur road',
#  'Name': 'Tamilarasu',
#  'Phone number': 9789929179,
#  'Place': 'Chennai',
#  '_id': ObjectId('63b659e76491258df9e7397d')}
# {'Address': '12,GW road',
#  'Name': 'Tamilarasu',
#  'Phone number': 9789929179,
#  'Place': 'Chennai',
#  '_id': ObjectId('63b667116491258df9e7397e')}
# {'Address': '18,MG road',
#  'Name': 'Chandru',
#  'Phone number': 9897689972,
#  'Place': 'Chennai',
#  '_id': ObjectId('63b667116491258df9e7397f')}
# {'Address': '12,Thevar road',
#  'Name': 'Kumaran',
#  'Phone number': 8974562321,
#  'Place': 'Madurai',
#  '_id': ObjectId('63b667116491258df9e73980')}
# {'Address': '15,Anna road',
#  'Name': 'Madhan',
#  'Phone number': 8523697412,
#  'Place': 'Coimbatore',
#  '_id': ObjectId('63b667116491258df9e73981')}
# {'Address': '14,AS road',
#  'Name': 'Mano',
#  'Phone number': 9874563214,
#  'Place': 'Chennai',
#  '_id': ObjectId('63b667116491258df9e73982')}
# {'Address': '12,GP road',
#  'Name': 'Tharun',
# ...

# %%
# to make a query and find the records

Query = {'Place':'Chennai'}

for i in my_coll.find(Query):
    print(i)
# Out:
# {'_id': ObjectId('63b659e76491258df9e7397d'), 'Name': 'Tamilarasu', 'Phone number': 9789929179, 'Place': 'Chennai', 'Address': 'Gerugambakkam, porur road'}
# {'_id': ObjectId('63b667116491258df9e7397e'), 'Name': 'Tamilarasu', 'Phone number': 9789929179, 'Place': 'Chennai', 'Address': '12,GW road'}
# {'_id': ObjectId('63b667116491258df9e7397f'), 'Name': 'Chandru', 'Phone number': 9897689972, 'Place': 'Chennai', 'Address': '18,MG road'}
# {'_id': ObjectId('63b667116491258df9e73982'), 'Name': 'Mano', 'Phone number': 9874563214, 'Place': 'Chennai', 'Address': '14,AS road'}
# {'_id': ObjectId('63b667116491258df9e73984'), 'Name': 'Arunachalam', 'Phone number': 9874529179, 'Place': 'Chennai', 'Address': '12,MM road'}
# {'_id': ObjectId('63b667116491258df9e73985'), 'Name': 'Balaraja', 'Phone number': 9789926547, 'Place': 'Chennai', 'Address': '12,Warren road'}
# ...

# %%
Query = {'Place':'Madurai'}

for i in my_coll.find((Query),{'Name':1,'_id':0}):
    print(i)
# Out:
# {'Name': 'Kumaran'}
# {'Name': 'Sanjeev'}
# {'Name': 'Walter'}
# {'Name': 'Kumaran'}
# {'Name': 'Sanjeev'}
# {'Name': 'Walter'}
# {'Name': 'Kumaran'}
# {'Name': 'Sanjeev'}
# {'Name': 'Walter'}
# {'Name': 'Kumaran'}
# {'Name': 'Sanjeev'}
# {'Name': 'Walter'}

# %%
Query = {'Place':'Chennai'}

for i in my_coll.find((Query),{'_id':0,'Name':1,'Address':1}):
    print(i)
# Out:
# {'Name': 'Tamilarasu', 'Address': 'Gerugambakkam, porur road'}
# {'Name': 'Tamilarasu', 'Address': '12,GW road'}
# {'Name': 'Chandru', 'Address': '18,MG road'}
# {'Name': 'Mano', 'Address': '14,AS road'}
# {'Name': 'Arunachalam', 'Address': '12,MM road'}
# {'Name': 'Balaraja', 'Address': '12,Warren road'}
# {'Name': 'Nani', 'Address': '12,Poonamalle road'}
# {'Name': 'Elvis', 'Address': '12,Army road'}
# {'Name': 'kesavan', 'Address': '12,Nill road'}
# {'Name': 'Chandru', 'Address': '18,MG road'}
# {'Name': 'Mano', 'Address': '14,AS road'}
# {'Name': 'Arunachalam', 'Address': '12,MM road'}
# {'Name': 'Balaraja', 'Address': '12,Warren road'}
# {'Name': 'Nani', 'Address': '12,Poonamalle road'}
# {'Name': 'Elvis', 'Address': '12,Army road'}
# {'Name': 'kesavan', 'Address': '12,Nill road'}
# {'Name': 'Tamilarasu', 'Address': '12,GW road'}
# {'Name': 'Chandru', 'Address': '18,MG road'}
# {'Name': 'Mano', 'Address': '14,AS road'}
# {'Name': 'Arunachalam', 'Address': '12,MM road'}
# ...

# %%
# to modify the records using update_one() method
# create a query and update
query = {'Name':'Chandru'}
update = {'$set':{'Address':'Gerugambakkam, porur road'}}

# %%
# to insert a document using update_one() method

my_coll.update_one(query,update)

# %%
# to view the updated record

for i in my_coll.find():
    print(i)
# Out:
# {'_id': ObjectId('63b659e76491258df9e7397d'), 'Name': 'Tamilarasu', 'Phone number': 9789929179, 'Place': 'Chennai', 'Address': 'Gerugambakkam, porur road'}
# {'_id': ObjectId('63b667116491258df9e7397e'), 'Name': 'Tamilarasu', 'Phone number': 9789929179, 'Place': 'Chennai', 'Address': '12,GW road'}
# {'_id': ObjectId('63b667116491258df9e7397f'), 'Name': 'Chandru', 'Phone number': 9897689972, 'Place': 'Chennai', 'Address': 'Gerugambakkam, porur road'}
# {'_id': ObjectId('63b667116491258df9e73980'), 'Name': 'Kumaran', 'Phone number': 8974562321, 'Place': 'Madurai', 'Address': '12,Thevar road'}
# {'_id': ObjectId('63b667116491258df9e73981'), 'Name': 'Madhan', 'Phone number': 8523697412, 'Place': 'Coimbatore', 'Address': '15,Anna road'}
# {'_id': ObjectId('63b667116491258df9e73982'), 'Name': 'Mano', 'Phone number': 9874563214, 'Place': 'Chennai', 'Address': '14,AS road'}
# ...

# %%
# to modify the records using update_many() method
# create a query and update
query = {'Place':'Chennai'}
update = {'$set':{'Place':'Madras'}}

# %%
# to insert a document using update_one() method

my_coll.update_many(query,update)

# %%
# to view the updated record

for i in my_coll.find():
    print(i)
# Out:
# {'_id': ObjectId('63b659e76491258df9e7397d'), 'Name': 'Tamilarasu', 'Phone number': 9789929179, 'Place': 'Madras', 'Address': 'Gerugambakkam, porur road'}
# {'_id': ObjectId('63b667116491258df9e7397e'), 'Name': 'Tamilarasu', 'Phone number': 9789929179, 'Place': 'Madras', 'Address': '12,GW road'}
# {'_id': ObjectId('63b667116491258df9e7397f'), 'Name': 'Chandru', 'Phone number': 9897689972, 'Place': 'Madras', 'Address': 'Gerugambakkam, porur road'}
# {'_id': ObjectId('63b667116491258df9e73980'), 'Name': 'Kumaran', 'Phone number': 8974562321, 'Place': 'Madurai', 'Address': '12,Thevar road'}
# {'_id': ObjectId('63b667116491258df9e73981'), 'Name': 'Madhan', 'Phone number': 8523697412, 'Place': 'Coimbatore', 'Address': '15,Anna road'}
# {'_id': ObjectId('63b667116491258df9e73982'), 'Name': 'Mano', 'Phone number': 9874563214, 'Place': 'Madras', 'Address': '14,AS road'}
# ...

# %%
for i in my_coll.find({},{'_id':0,'Name':1,'Address':1,'Place':1}):
    print(i)
# Out:
# {'Name': 'Tamilarasu', 'Place': 'Madras', 'Address': 'Gerugambakkam, porur road'}
# {'Name': 'Tamilarasu', 'Place': 'Madras', 'Address': '12,GW road'}
# {'Name': 'Chandru', 'Place': 'Madras', 'Address': 'Gerugambakkam, porur road'}
# {'Name': 'Kumaran', 'Place': 'Madurai', 'Address': '12,Thevar road'}
# {'Name': 'Madhan', 'Place': 'Coimbatore', 'Address': '15,Anna road'}
# {'Name': 'Mano', 'Place': 'Madras', 'Address': '14,AS road'}
# {'Name': 'Tharun', 'Place': 'Vellore', 'Address': '12,GP road'}
# {'Name': 'Arunachalam', 'Place': 'Madras', 'Address': '12,MM road'}
# {'Name': 'Balaraja', 'Place': 'Madras', 'Address': '12,Warren road'}
# {'Name': 'Rajamalai', 'Place': 'Coimbatore', 'Address': '12,BB road'}
# {'Name': 'Sanjeev', 'Place': 'Madurai', 'Address': '12,Pettai road'}
# {'Name': 'Nani', 'Place': 'Madras', 'Address': '12,Poonamalle road'}
# {'Name': 'Maaran', 'Place': 'Coimbatore', 'Address': '12,Poes road'}
# {'Name': 'Walter', 'Place': 'Madurai', 'Address': '12,LB road'}
# ...

# %%
# to update two query's

q = {'Name':'Kumaran'}
u = {'$set':{'Pnone number':'04425897','Place':'Salem'}}

# %%
# to update in the collection

my_coll.update_one(q,u)

# %%
for i in my_coll.find({},{'_id':0}):
    print(i)
# Out:
# {'Name': 'Tamilarasu', 'Phone number': 9789929179, 'Place': 'Madras', 'Address': 'Gerugambakkam, porur road'}
# {'Name': 'Tamilarasu', 'Phone number': 9789929179, 'Place': 'Madras', 'Address': '12,GW road'}
# {'Name': 'Chandru', 'Phone number': 9897689972, 'Place': 'Madras', 'Address': 'Gerugambakkam, porur road'}
# {'Name': 'Kumaran', 'Phone number': 8974562321, 'Place': 'Salem', 'Address': '12,Thevar road', 'Pnone number': '04425897'}
# {'Name': 'Madhan', 'Phone number': 8523697412, 'Place': 'Coimbatore', 'Address': '15,Anna road'}
# {'Name': 'Mano', 'Phone number': 9874563214, 'Place': 'Madras', 'Address': '14,AS road'}
# {'Name': 'Tharun', 'Phone number': 9789925896, 'Place': 'Vellore', 'Address': '12,GP road'}
# {'Name': 'Arunachalam', 'Phone number': 9874529179, 'Place': 'Madras', 'Address': '12,MM road'}
# {'Name': 'Balaraja', 'Phone number': 9789926547, 'Place': 'Madras', 'Address': '12,Warren road'}
# ...

# %%
# to delete the records by using delete_one() method

my_coll.delete_one({'Name':'Elvis'})

# %%
for i in my_coll.find({},{'_id':0}):
    print(i)
# Out:
# {'Name': 'Tamilarasu', 'Phone number': 9789929179, 'Place': 'Madras', 'Address': 'Gerugambakkam, porur road'}
# {'Name': 'Tamilarasu', 'Phone number': 9789929179, 'Place': 'Madras', 'Address': '12,GW road'}
# {'Name': 'Chandru', 'Phone number': 9897689972, 'Place': 'Madras', 'Address': 'Gerugambakkam, porur road'}
# {'Name': 'Kumaran', 'Phone number': 8974562321, 'Place': 'Salem', 'Address': '12,Thevar road', 'Pnone number': '04425897'}
# {'Name': 'Madhan', 'Phone number': 8523697412, 'Place': 'Coimbatore', 'Address': '15,Anna road'}
# {'Name': 'Mano', 'Phone number': 9874563214, 'Place': 'Madras', 'Address': '14,AS road'}
# {'Name': 'Tharun', 'Phone number': 9789925896, 'Place': 'Vellore', 'Address': '12,GP road'}
# {'Name': 'Arunachalam', 'Phone number': 9874529179, 'Place': 'Madras', 'Address': '12,MM road'}
# {'Name': 'Balaraja', 'Phone number': 9789926547, 'Place': 'Madras', 'Address': '12,Warren road'}
# ...

# %%
# to delete all the document by using delete_many() method

my_coll.delete_many({'Name':'Elvis'})

# %%
for i in my_coll.find({},{'_id':0}):
    print(i)
# Out:
# {'Name': 'Tamilarasu', 'Phone number': 9789929179, 'Place': 'Madras', 'Address': 'Gerugambakkam, porur road'}
# {'Name': 'Tamilarasu', 'Phone number': 9789929179, 'Place': 'Madras', 'Address': '12,GW road'}
# {'Name': 'Chandru', 'Phone number': 9897689972, 'Place': 'Madras', 'Address': 'Gerugambakkam, porur road'}
# {'Name': 'Kumaran', 'Phone number': 8974562321, 'Place': 'Salem', 'Address': '12,Thevar road', 'Pnone number': '04425897'}
# {'Name': 'Madhan', 'Phone number': 8523697412, 'Place': 'Coimbatore', 'Address': '15,Anna road'}
# {'Name': 'Mano', 'Phone number': 9874563214, 'Place': 'Madras', 'Address': '14,AS road'}
# {'Name': 'Tharun', 'Phone number': 9789925896, 'Place': 'Vellore', 'Address': '12,GP road'}
# {'Name': 'Arunachalam', 'Phone number': 9874529179, 'Place': 'Madras', 'Address': '12,MM road'}
# {'Name': 'Balaraja', 'Phone number': 9789926547, 'Place': 'Madras', 'Address': '12,Warren road'}
# ...
